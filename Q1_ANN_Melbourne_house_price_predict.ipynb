# %% [markdown]
# # 0. Mount drive & Import packaged

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# %cd '/content/gdrive/My Drive/LDS8_K270_ONLINE_DamThiMinhPhuong/LDS8_K270_DamThiMinhPhuong_Cuoi_ky/Question1_ANN'
# Out:
# /content/gdrive/My Drive/LDS8_K270_ONLINE_DamThiMinhPhuong/LDS8_K270_DamThiMinhPhuong_Cuoi_ky/Question1_ANN

# %%
import pandas as pd
from tensorflow.keras.models import load_model

# %% [markdown]
# # 1. Load data

# %%
df_null = pd.read_csv('Dataset/MELBOURNE_HOUSE_PRICES_PREDICT.csv')
df_null.head()
# Out:
#    Rooms  Price  Distance  ...  Method_SS  Method_VB  Method_W
# 0      6    NaN      14.0  ...          0          0         0
# 1      4    NaN      15.5  ...          0          0         0
# 2      4    NaN      10.2  ...          0          0         0
# 3      4    NaN      16.5  ...          0          0         0
# 4      3    NaN       9.7  ...          0          0         0
#
# [5 rows x 392 columns]

# %%
df_null.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14588 entries, 0 to 14587
# Columns: 392 entries, Rooms to Method_W
# dtypes: float64(2), int64(390)
# memory usage: 43.6 MB

# %%
X = df_null.drop('Price', axis=1)

# %%
X.head()
# Out:
#    Rooms  Distance  Suburb_Aberfeldie  ...  Method_SS  Method_VB  Method_W
# 0      6      14.0                  0  ...          0          0         0
# 1      4      15.5                  0  ...          0          0         0
# 2      4      10.2                  0  ...          0          0         0
# 3      4      16.5                  0  ...          0          0         0
# 4      3       9.7                  0  ...          0          0         0
#
# [5 rows x 391 columns]

# %% [markdown]
# # 2. Load model & Predict

# %%
# Load model
model = load_model('ANN_houseprice_model.h5')

# %%
# Make new predict
y_pred = model.predict(X)

# %%
y_pred[:5]
# Out:
# array([[ 881726.9],
#        [ 673243.5],
#        [1931646. ],
#        [ 714032.5],
#        [1603359.8]], dtype=float32)

# %%
# update Predicted price to df_null
df_null.Price = y_pred

# %%
df_null.head()
# Out:
#    Rooms        Price  Distance  ...  Method_SS  Method_VB  Method_W
# 0      6   881726.875      14.0  ...          0          0         0
# 1      4   673243.500      15.5  ...          0          0         0
# 2      4  1931646.000      10.2  ...          0          0         0
# 3      4   714032.500      16.5  ...          0          0         0
# 4      3  1603359.750       9.7  ...          0          0         0
#
# [5 rows x 392 columns]
